# %%
import json
import requests

api_key = '???'
url = 'http://api.tvmedia.ca/tv/v4/lineups/36617/listings?api_key=%s&timezone=America/New_York&showtype[]=M&showtype[]=6&detail=brief' % (api_key)
response = requests.get(url)
data = response.json()
data
# Out:
# [{'stationID': 615,
#   'name': 'BBC America - East',
#   'callsign': 'BBC',
#   'network': '',
#   'stationType': 'Cable',
#   'webLink': 'http://www.bbcamerica.com/',
#   'logoFilename': 'bbcamerica.png',
#   'listingID': 499371573,
#   'listDateTime': '2019-04-25 15:00:00',
#   'duration': 208,
#   'showID': 284976,
#   'seriesID': 119608,
#   'showName': 'Movie',
#   'episodeTitle': 'The Patriot',
#   'episodeNumber': '2000                     ',
#   'parts': 0,
#   'partNum': 0,
#   'seriesPremiere': False,
#   'seasonPremiere': False,
#   'seriesFinale': False,
#   'seasonFinale': False,
#   'repeat': False,
#   'new': False,
#   'rating': 'TVMA',
#   'captioned': True,
#   'educational': False,
#   'blackWhite': False,
#   'subtitled': False,
#   'live': False,
#   'hd': False,
#   'descriptiveVideo': False,
#   'inProgress': False,
#   'showTypeID': 'M',
#   'breakoutLevel': 3,
#   'showType': 'Movies, Drama',
#   'year': '2000',
#   'guest': '',
# ...

# %%
#Code sample written by Steven Sfikas
